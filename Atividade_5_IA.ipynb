# %% [markdown]
# #**Atividade 5 - Redes Neurais**
#
# Pedro Freitas M. Barbosa    |   22.218.013-5
#
# Guilherme Ormond Sampaio    | 22.218.007-7
#
# Leon Ferreira Bellini | 22.218.002-8
#
# Felipe Maciel de Sousa | 22.218.042-4

# %% [markdown]
# ###Importando as bibliotecas que serão utilizadas.

# %%
#Importando as bibliotecas
import statistics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor

# %matplotlib inline

# %% [markdown]
# ###Carga das bases de dados.

# %% [markdown]
# ####Carga do arquivo de teste 1

# %%
arquivo = np.load('teste1.npy')
x1 = arquivo[0]
y1 = arquivo[1]

plt.figure(figsize = (16,8))
plt.plot(x1,y1)
plt.show()

# %% [markdown]
# ####Carga do arquivo de teste 2

# %%
arquivo = np.load('teste2.npy')
x2 = arquivo[0]
y2 = arquivo[1]

plt.figure(figsize = (16,8))
plt.plot(x2,y2)
plt.show()

# %% [markdown]
# ####Carga do arquivo de teste 3

# %%
arquivo = np.load('teste3.npy')
x3 = arquivo[0]
y3 = arquivo[1]

plt.figure(figsize = (16,8))
plt.plot(x3,y3)
plt.show()

# %% [markdown]
# ####Carga do arquivo de teste 4

# %%
arquivo = np.load('teste4.npy')
x4 = arquivo[0]
y4 = arquivo[1]

plt.figure(figsize = (16,8))
plt.plot(x4,y4)
plt.show()

# %% [markdown]
# ####Carga do arquivo de teste 5

# %%
arquivo = np.load('teste5.npy')
x5 = arquivo[0]
y5 = arquivo[1]

plt.figure(figsize = (16,8))
plt.plot(x5,y5)
plt.show()

# %% [markdown]
# ###Realizando aproximação de funções com MLP

# %% [markdown]
# ####Arquivo de teste 1

# %%
regr1 = MLPRegressor (hidden_layer_sizes = (4,4),
                     max_iter = 10000,
                     activation = 'identity',
                     solver = 'adam',
                     learning_rate = 'adaptive',
                     n_iter_no_change = 1000
)

m1 = []
for _ in range(50):
  regr1 = regr1.fit(x1,y1)
  m1.append(regr1.best_loss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-917f272eb402> in <module>()
#       9 mean = []
#      10 for _ in range(50):
# ---> 11   regr1 = regr1.fit(x1,y1)
#      12   mean.append(regr1.best_loss)
#
# NameError: name 'x1' is not defined

# %% [markdown]
# ####Arquivo de teste 2

# %%
regr2 = MLPRegressor (hidden_layer_sizes = (4,4),
                     max_iter = 10000,
                     activation = 'identity',
                     solver = 'adam',
                     learning_rate = 'adaptive',
                     n_iter_no_change = 1000
)

m2 = []
for _ in range(50):
  regr2 = regr2.fit(x2,y2)
  m2.append(regr2.best_loss_)

print(f'Média de loss: {statistics.mean(m2)}')
print(f'Desvio padráo de loss: {statistics.pstdev(m2)}')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ####Arquivo de teste 3

# %%
regr3 = MLPRegressor (hidden_layer_sizes = (15,15),
                     max_iter = 10000,
                     activation = 'relu',
                     solver = 'adam',
                     learning_rate = 'adaptive',
                     n_iter_no_change = 1000
)

m3 = []
for _ in range(50):
  regr3 = regr3.fit(x3,y3)
  m3.append(regr3.best_loss_)

print(f'Média de loss: {statistics.mean(m3)}')
print(f'Desvio padráo de loss: {statistics.pstdev(m3)}')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ####Arquivo de teste 4

# %%
regr4 = MLPRegressor (hidden_layer_sizes = (40,35),
                     max_iter = 10000,
                     activation = 'relu',
                     solver = 'adam',
                     learning_rate = 'adaptive',
                     n_iter_no_change = 1000
)

m4 = []
for _ in range(50):
  regr4 = regr4.fit(x4,y4)
  m4.append(regr4.best_loss_)

print(f'Média de loss: {statistics.mean(m4)}')
print(f'Desvio padráo de loss: {statistics.pstdev(m4)}')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ####Arquivo de teste 5

# %%
regr5 = MLPRegressor (hidden_layer_sizes = (300, 300, 300, 300, 300),
                     max_iter = 10000,
                     activation = 'tanh',
                     solver = 'adam',
                     learning_rate = 'adaptive',
                     n_iter_no_change = 1000
)

m5 = []
for _ in range(5):
  regr5 = regr5.fit(x5,y5)
  m5.append(regr5.best_loss_)

print(f'Média de loss: {statistics.mean(m5)}')
print(f'Desvio padráo de loss: {statistics.pstdev(m5)}')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ###Curva de Aprendizagem

# %% [markdown]
# ####Arquivo de teste 1

# %%
plt.figure(figsize=(16,8))
plt.plot(regr1.loss_curve_)
plt.show()

# %% [markdown]
# ####Arquivo de teste 2

# %%
plt.figure(figsize=(16,8))
plt.plot(regr2.loss_curve_)
plt.show()

# %% [markdown]
# ####Arquivo de teste 3

# %%
plt.figure(figsize=(16,8))
plt.plot(regr3.loss_curve_)
plt.show()

# %% [markdown]
# ####Arquivo de teste 4

# %%
plt.figure(figsize=(16,8))
plt.plot(regr4.loss_curve_)
plt.show()

# %% [markdown]
# ####Arquivo de teste 5

# %%
plt.figure(figsize=(16,8))
plt.plot(regr5.loss_curve_)
plt.show()

# %% [markdown]
# ###Resultado Final

# %% [markdown]
# ####Arquivo de teste 1

# %%
y_est1 = regr1.predict(x1)

plt.figure(figsize=(16,8))
plt.plot(x1,y1,x1,y_est1)
plt.show()

# %% [markdown]
# ####Arquivo de teste 2

# %%
y_est2 = regr2.predict(x2)

plt.figure(figsize=(16,8))
plt.plot(x2,y2,x2,y_est2)
plt.show()

# %% [markdown]
# ####Arquivo de teste 3

# %%
y_est3 = regr3.predict(x3)

plt.figure(figsize=(16,8))
plt.plot(x3,y3,x3,y_est3)
plt.show()

# %% [markdown]
# ####Arquivo de teste 4

# %%
y_est4 = regr4.predict(x4)

plt.figure(figsize=(16,8))
plt.plot(x4,y4,x4,y_est4)
plt.show()

# %% [markdown]
# ####Arquivo de teste 5

# %%
y_est5 = regr5.predict(x5)

plt.figure(figsize=(16,8))
plt.plot(x5,y5,x5,y_est5)
plt.show()
